# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import data
base_dir = "D:\elastic-hurryup"
columns_names = ['tid', 'start', 'end', 'query', 'dif', 'keylength']
ghz26_scale50 = pd.read_csv(base_dir + '\\db\\frequencies-scale50\\2.6ghz\\log.txt', names=columns_names)
ghz23_scale50 = pd.read_csv(base_dir + '\\db\\frequencies-scale50\\2.3ghz\\log.txt', names=columns_names)
ghz20_scale50 = pd.read_csv(base_dir + '\\db\\frequencies-scale50\\2.0ghz\\log.txt', names=columns_names)
ghz17_scale50 = pd.read_csv(base_dir + '\\db\\frequencies-scale50\\1.7ghz\\log.txt', names=columns_names)
ghz13_scale50 = pd.read_csv(base_dir + '\\db\\frequencies-scale50\\1.3ghz\\log.txt', names=columns_names)
ghz10_scale50 = pd.read_csv(base_dir + '\\db\\frequencies-scale50\\1.0ghz\\log.txt', names=columns_names)

qps10 = pd.read_csv(base_dir + '\\db\\qps\\scale10\\log.txt', names=columns_names)
qps05 = pd.read_csv(base_dir + '\\db\\qps\\scale5\\log.txt', names=columns_names)
qps30 = pd.read_csv(base_dir + '\\db\\qps\\scale30\\log.txt', names=columns_names)

async_exp = pd.read_csv(base_dir + '\\db\\async-exp\\log.txt', names=columns_names)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-a2b95c761e95> in <module>
#       2 base_dir = "D:\elastic-hurryup"
#       3 columns_names = ['tid', 'start', 'end', 'query', 'dif', 'keylength']
# ----> 4 ghz26_scale50 = pd.read_csv(base_dir + '\\db\\frequencies-scale50\\2.6ghz\\log.txt', names=columns_names)
#       5 ghz23_scale50 = pd.read_csv(base_dir + '\\db\\frequencies-scale50\\2.3ghz\\log.txt', names=columns_names)
#       6 ghz20_scale50 = pd.read_csv(base_dir + '\\db\\frequencies-scale50\\2.0ghz\\log.txt', names=columns_names)
#
# ...

# %%
ghz10 = pd.read_csv(base_dir + '\\db\\frequencies-noqueue\\1.0ghz-noqueue\\log.txt', names=columns_names)
ghz10['keylength'] = ghz10['query'].str.count('\+') + 1
ghz10_means = [ghz10[ghz10['keylength'] == 1]['dif'].mean(), ghz10[ghz10['keylength'] == 2]['dif'].mean(),
         ghz10[ghz10['keylength'] == 3]['dif'].mean(), ghz10[ghz10['keylength'] == 4]['dif'].mean(),
         ghz10[ghz10['keylength'] == 12]['dif'].mean(), ghz10[ghz10['keylength'] == 13]['dif'].mean(),
         ghz10[ghz10['keylength'] == 14]['dif'].mean(), ghz10[ghz10['keylength'] == 15]['dif'].mean(),
         ghz10[ghz10['keylength'] == 16]['dif'].mean()]

# %%
ghz26_scale50['keylength'] = ghz26_scale50['query'].str.count('\+') + 1
ghz23_scale50['keylength'] = ghz23_scale50['query'].str.count('\+') + 1
ghz20_scale50['keylength'] = ghz20_scale50['query'].str.count('\+') + 1
ghz17_scale50['keylength'] = ghz17_scale50['query'].str.count('\+') + 1
ghz13_scale50['keylength'] = ghz13_scale50['query'].str.count('\+') + 1
ghz10_scale50['keylength'] = ghz10_scale50['query'].str.count('\+') + 1
qps10['keylength'] = qps10['query'].str.count('\+') + 1
qps05['keylength'] = qps05['query'].str.count('\+') + 1
qps30['keylength'] = qps30['query'].str.count('\+') + 1
async_exp['keylength'] = async_exp['query'].str.count('\+') + 1

ghz26_scale50['dif'] = ghz26_scale50['dif']
ghz23_scale50['dif'] = ghz23_scale50['dif']
ghz20_scale50['dif'] = ghz20_scale50['dif']
ghz17_scale50['dif'] = ghz17_scale50['dif']
ghz13_scale50['dif'] = ghz13_scale50['dif']
ghz10_scale50['dif'] = ghz10_scale50['dif']
qps10['dif'] = qps10['dif']
qps05['dif'] = qps05['dif']
qps30['dif'] = qps30['dif']
async_exp['dif'] = async_exp['dif']

# %%
#Should add _scale50 to this work properly

fig, axs = plt.subplots(3, 2, figsize=(18,20), dpi=300)

labels = ['1', '2', '3', '4', '12', '13', '14', '15', '16']
x = np.arange(len(labels))
width = 0.35
fig.suptitle('Service Time for Varying Frequencies with Scales = 50', fontsize=22)

ghz26_means = [ghz26[ghz26['keylength'] == 1]['dif'].mean(), ghz26[ghz26['keylength'] == 2]['dif'].mean(),
         ghz26[ghz26['keylength'] == 3]['dif'].mean(), ghz26[ghz26['keylength'] == 4]['dif'].mean(),
         ghz26[ghz26['keylength'] == 12]['dif'].mean(), ghz26[ghz26['keylength'] == 13]['dif'].mean(),
         ghz26[ghz26['keylength'] == 14]['dif'].mean(), ghz26[ghz26['keylength'] == 15]['dif'].mean(),
         ghz26[ghz26['keylength'] == 16]['dif'].mean()]
ghz26_std = [ np.std(ghz26[ghz26['keylength'] == 1]['dif']), np.std(ghz26[ghz26['keylength'] == 2]['dif']), 
       np.std(ghz26[ghz26['keylength'] == 3]['dif']), np.std(ghz26[ghz26['keylength'] == 4]['dif']),
       np.std(ghz26[ghz26['keylength'] == 12]['dif']), np.std(ghz26[ghz26['keylength'] == 13]['dif']),
       np.std(ghz26[ghz26['keylength'] == 14]['dif']), np.std(ghz26[ghz26['keylength'] == 15]['dif']),
       np.std(ghz26[ghz26['keylength'] == 16]['dif'])]

ghz23_means = [ghz23[ghz23['keylength'] == 1]['dif'].mean(), ghz23[ghz23['keylength'] == 2]['dif'].mean(),
         ghz23[ghz23['keylength'] == 3]['dif'].mean(), ghz23[ghz23['keylength'] == 4]['dif'].mean(),
         ghz23[ghz23['keylength'] == 12]['dif'].mean(), ghz23[ghz23['keylength'] == 13]['dif'].mean(),
         ghz23[ghz23['keylength'] == 14]['dif'].mean(), ghz23[ghz23['keylength'] == 15]['dif'].mean(),
         ghz23[ghz23['keylength'] == 16]['dif'].mean()]
ghz23_std = [ np.std(ghz23[ghz23['keylength'] == 1]['dif']), np.std(ghz23[ghz23['keylength'] == 2]['dif']), 
       np.std(ghz23[ghz23['keylength'] == 3]['dif']), np.std(ghz23[ghz23['keylength'] == 4]['dif']),
       np.std(ghz23[ghz23['keylength'] == 12]['dif']), np.std(ghz23[ghz23['keylength'] == 13]['dif']),
       np.std(ghz23[ghz23['keylength'] == 14]['dif']), np.std(ghz23[ghz23['keylength'] == 15]['dif']),
       np.std(ghz23[ghz23['keylength'] == 16]['dif'])]
ghz20_means = [ghz20[ghz20['keylength'] == 1]['dif'].mean(), ghz20[ghz20['keylength'] == 2]['dif'].mean(),
         ghz20[ghz20['keylength'] == 3]['dif'].mean(), ghz20[ghz20['keylength'] == 4]['dif'].mean(),
         ghz20[ghz20['keylength'] == 12]['dif'].mean(), ghz20[ghz20['keylength'] == 13]['dif'].mean(),
         ghz20[ghz20['keylength'] == 14]['dif'].mean(), ghz20[ghz20['keylength'] == 15]['dif'].mean(),
         ghz20[ghz20['keylength'] == 16]['dif'].mean()]
ghz20_std = [ np.std(ghz20[ghz20['keylength'] == 1]['dif']), np.std(ghz20[ghz20['keylength'] == 2]['dif']), 
       np.std(ghz20[ghz20['keylength'] == 3]['dif']), np.std(ghz20[ghz20['keylength'] == 4]['dif']),
       np.std(ghz20[ghz20['keylength'] == 12]['dif']), np.std(ghz20[ghz20['keylength'] == 13]['dif']),
       np.std(ghz20[ghz20['keylength'] == 14]['dif']), np.std(ghz20[ghz20['keylength'] == 15]['dif']),
       np.std(ghz20[ghz20['keylength'] == 16]['dif'])]
ghz17_means = [ghz17[ghz17['keylength'] == 1]['dif'].mean(), ghz17[ghz17['keylength'] == 2]['dif'].mean(),
         ghz17[ghz17['keylength'] == 3]['dif'].mean(), ghz17[ghz17['keylength'] == 4]['dif'].mean(),
         ghz17[ghz17['keylength'] == 12]['dif'].mean(), ghz17[ghz17['keylength'] == 13]['dif'].mean(),
         ghz17[ghz17['keylength'] == 14]['dif'].mean(), ghz17[ghz17['keylength'] == 15]['dif'].mean(),
         ghz17[ghz17['keylength'] == 16]['dif'].mean()]
ghz17_std = [ np.std(ghz17[ghz17['keylength'] == 1]['dif']), np.std(ghz17[ghz17['keylength'] == 2]['dif']), 
       np.std(ghz17[ghz17['keylength'] == 3]['dif']), np.std(ghz17[ghz17['keylength'] == 4]['dif']),
       np.std(ghz17[ghz17['keylength'] == 12]['dif']), np.std(ghz17[ghz17['keylength'] == 13]['dif']),
       np.std(ghz17[ghz17['keylength'] == 14]['dif']), np.std(ghz17[ghz17['keylength'] == 15]['dif']),
       np.std(ghz17[ghz17['keylength'] == 16]['dif'])]
ghz13_means = [ghz13[ghz13['keylength'] == 1]['dif'].mean(), ghz13[ghz13['keylength'] == 2]['dif'].mean(),
         ghz13[ghz13['keylength'] == 3]['dif'].mean(), ghz13[ghz13['keylength'] == 4]['dif'].mean(),
         ghz13[ghz13['keylength'] == 12]['dif'].mean(), ghz13[ghz13['keylength'] == 13]['dif'].mean(),
         ghz13[ghz13['keylength'] == 14]['dif'].mean(), ghz13[ghz13['keylength'] == 15]['dif'].mean(),
         ghz13[ghz13['keylength'] == 16]['dif'].mean()]
ghz13_std = [ np.std(ghz13[ghz13['keylength'] == 1]['dif']), np.std(ghz13[ghz13['keylength'] == 2]['dif']), 
       np.std(ghz13[ghz13['keylength'] == 3]['dif']), np.std(ghz13[ghz13['keylength'] == 4]['dif']),
       np.std(ghz13[ghz13['keylength'] == 12]['dif']), np.std(ghz13[ghz13['keylength'] == 13]['dif']),
       np.std(ghz13[ghz13['keylength'] == 14]['dif']), np.std(ghz13[ghz13['keylength'] == 15]['dif']),
       np.std(ghz13[ghz13['keylength'] == 16]['dif'])]
ghz10_means = [ghz10[ghz10['keylength'] == 1]['dif'].mean(), ghz10[ghz10['keylength'] == 2]['dif'].mean(),
         ghz10[ghz10['keylength'] == 3]['dif'].mean(), ghz10[ghz10['keylength'] == 4]['dif'].mean(),
         ghz10[ghz10['keylength'] == 12]['dif'].mean(), ghz10[ghz10['keylength'] == 13]['dif'].mean(),
         ghz10[ghz10['keylength'] == 14]['dif'].mean(), ghz10[ghz10['keylength'] == 15]['dif'].mean(),
         ghz10[ghz10['keylength'] == 16]['dif'].mean()]
ghz10_std = [ np.std(ghz10[ghz10['keylength'] == 1]['dif']), np.std(ghz10[ghz10['keylength'] == 2]['dif']), 
       np.std(ghz10[ghz10['keylength'] == 3]['dif']), np.std(ghz10[ghz10['keylength'] == 4]['dif']),
       np.std(ghz10[ghz10['keylength'] == 12]['dif']), np.std(ghz10[ghz10['keylength'] == 13]['dif']),
       np.std(ghz10[ghz10['keylength'] == 14]['dif']), np.std(ghz10[ghz10['keylength'] == 15]['dif']),
       np.std(ghz10[ghz10['keylength'] == 16]['dif'])]


ax = axs[0][0]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
ax.set_title('Freq@2.6GHz', fontsize=16)
ax.set_xticks(x)
#ax.set_ylim(0, 6000)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.bar(x, ghz26_means, width, yerr=ghz26_std)
ax = axs[0][1]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
ax.set_title('Freq@2.3GHz', fontsize=16)
ax.set_xticks(x)
#ax.set_ylim(0, 6000)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.bar(x, ghz23_means, width, yerr=ghz23_std)
ax = axs[1][0]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
ax.set_title('Freq@2.0GHz', fontsize=16)
ax.set_xticks(x)
#ax.set_ylim(0, 6000)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.bar(x, ghz20_means, width, yerr=ghz20_std)
ax = axs[1][1]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
ax.set_title('Freq@1.7GHz', fontsize=16)
ax.set_xticks(x)
#ax.set_ylim(0, 6000)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.bar(x, ghz17_means, width, yerr=ghz17_std)
ax = axs[2][0]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
ax.set_title('Freq@1.3GHz', fontsize=16)
ax.set_xticks(x)
#ax.set_ylim(0, 6000)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.bar(x, ghz13_means, width, yerr=ghz13_std)
ax = axs[2][1]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
ax.set_title('Freq@1.0GHz', fontsize=16)
ax.set_xticks(x)
#ax.set_ylim(0, 6000)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.bar(x, ghz10_means, width, yerr=ghz10_std)
fig.tight_layout()
fig.subplots_adjust(top=0.88)
plt.show()
fig.savefig('D:\\elastic-hurryup\\graphs\\frequencies.png')

# %%
#Should add _scale50 (ghz26) to this work properly
fig, axs = plt.subplots(2,2, figsize=(14,12), dpi=300)

labels = ['1', '2', '3', '4', '12', '13', '14', '15', '16']
x = np.arange(len(labels))
width = 0.35
means_10 = [ qps10[qps10['keylength'] == 1]['dif'].mean(), qps10[qps10['keylength'] == 2]['dif'].mean(),
         qps10[qps10['keylength'] == 3]['dif'].mean(), qps10[qps10['keylength'] == 4]['dif'].mean(),
         qps10[qps10['keylength'] == 12]['dif'].mean(), qps10[qps10['keylength'] == 13]['dif'].mean(),
         qps10[qps10['keylength'] == 14]['dif'].mean(), qps10[qps10['keylength'] == 15]['dif'].mean(),
         qps10[qps10['keylength'] == 16]['dif'].mean()]
std_10 = [ np.std(qps10[qps10['keylength'] == 1]['dif']), np.std(qps10[qps10['keylength'] == 2]['dif']), 
       np.std(qps10[qps10['keylength'] == 3]['dif']), np.std(qps10[qps10['keylength'] == 4]['dif']),
       np.std(qps10[qps10['keylength'] == 12]['dif']), np.std(qps10[qps10['keylength'] == 13]['dif']),
       np.std(qps10[qps10['keylength'] == 14]['dif']), np.std(qps10[qps10['keylength'] == 15]['dif']),
       np.std(qps10[qps10['keylength'] == 16]['dif'])]
means_30 = [ qps30[qps30['keylength'] == 1]['dif'].mean(), qps30[qps30['keylength'] == 2]['dif'].mean(),
         qps30[qps30['keylength'] == 3]['dif'].mean(), qps30[qps30['keylength'] == 4]['dif'].mean(),
         qps30[qps30['keylength'] == 12]['dif'].mean(), qps30[qps30['keylength'] == 13]['dif'].mean(),
         qps30[qps30['keylength'] == 14]['dif'].mean(), qps30[qps30['keylength'] == 15]['dif'].mean(),
         qps30[qps30['keylength'] == 16]['dif'].mean()]
std_30 = [ np.std(qps30[qps30['keylength'] == 1]['dif']), np.std(qps30[qps30['keylength'] == 2]['dif']), 
       np.std(qps30[qps30['keylength'] == 3]['dif']), np.std(qps30[qps30['keylength'] == 4]['dif']),
       np.std(qps30[qps30['keylength'] == 12]['dif']), np.std(qps30[qps30['keylength'] == 13]['dif']),
       np.std(qps30[qps30['keylength'] == 14]['dif']), np.std(qps30[qps30['keylength'] == 15]['dif']),
       np.std(qps30[qps30['keylength'] == 16]['dif'])]
means_05 = [ qps05[qps05['keylength'] == 1]['dif'].mean(), qps05[qps05['keylength'] == 2]['dif'].mean(),
         qps05[qps05['keylength'] == 3]['dif'].mean(), qps05[qps05['keylength'] == 4]['dif'].mean(),
         qps05[qps05['keylength'] == 12]['dif'].mean(), qps05[qps05['keylength'] == 13]['dif'].mean(),
         qps05[qps05['keylength'] == 14]['dif'].mean(), qps05[qps05['keylength'] == 15]['dif'].mean(),
         qps05[qps05['keylength'] == 16]['dif'].mean()]
std_05 = [ np.std(qps05[qps05['keylength'] == 1]['dif']), np.std(qps05[qps05['keylength'] == 2]['dif']), 
       np.std(qps05[qps05['keylength'] == 3]['dif']), np.std(qps05[qps05['keylength'] == 4]['dif']),
       np.std(qps05[qps05['keylength'] == 12]['dif']), np.std(qps05[qps05['keylength'] == 13]['dif']),
       np.std(qps05[qps05['keylength'] == 14]['dif']), np.std(qps05[qps05['keylength'] == 15]['dif']),
       np.std(qps05[qps05['keylength'] == 16]['dif'])]
means_50 = [ghz26[ghz26['keylength'] == 1]['dif'].mean(), ghz26[ghz26['keylength'] == 2]['dif'].mean(),
         ghz26[ghz26['keylength'] == 3]['dif'].mean(), ghz26[ghz26['keylength'] == 4]['dif'].mean(),
         ghz26[ghz26['keylength'] == 12]['dif'].mean(), ghz26[ghz26['keylength'] == 13]['dif'].mean(),
         ghz26[ghz26['keylength'] == 14]['dif'].mean(), ghz26[ghz26['keylength'] == 15]['dif'].mean(),
         ghz26[ghz26['keylength'] == 16]['dif'].mean()]
std_50 = [ np.std(ghz26[ghz26['keylength'] == 1]['dif']), np.std(ghz26[ghz26['keylength'] == 2]['dif']), 
       np.std(ghz26[ghz26['keylength'] == 3]['dif']), np.std(ghz26[ghz26['keylength'] == 4]['dif']),
       np.std(ghz26[ghz26['keylength'] == 12]['dif']), np.std(ghz26[ghz26['keylength'] == 13]['dif']),
       np.std(ghz26[ghz26['keylength'] == 14]['dif']), np.std(ghz26[ghz26['keylength'] == 15]['dif']),
       np.std(ghz26[ghz26['keylength'] == 16]['dif'])]

fig.suptitle('Service Time @ 2.6 GHz with varying load scales', fontsize=22)

ax = axs[0][0]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
ax.set_title('Scale = 5', fontsize=16)
ax.set_xticks(x)
ax.set_ylim(0, 6)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.bar(x, means_05, width, yerr=std_05)
ax = axs[0][1]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
ax.set_title('Scale = 10', fontsize=16)
ax.set_xticks(x)
ax.set_ylim(0, 10)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.bar(x, means_10, width, yerr=std_10)
ax = axs[1][0]
ax.set_xlabel('Keyword Length (unit)')
ax.set_ylabel('Service Time (ms)')
ax.set_title('Scale = 30', fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.set_ylim(0, 16)
ax.bar(x, means_30, width, yerr=std_30)
ax = axs[1][1]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
ax.set_title('Scale = 50', fontsize=16)
ax.set_xticks(x)
ax.set_ylim(0, 22)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.bar(x, means_50, width, yerr=std_50)
fig.tight_layout()
fig.subplots_adjust(top=0.88)
plt.show()
fig.savefig('D:\\elastic-hurryup\\graphs\\scales.png')

# %%
fig, axs = plt.subplots(1,2, figsize=(18,10), dpi=300)

labels = ['1', '2', '3', '4', '12', '13', '14', '15', '16']
x = np.arange(len(labels))
width = 0.35
fig.suptitle('Service Time on Async-Profiler @ 2.6GHz Scales=50', fontsize=22)

async_means = [ async_exp[async_exp['keylength'] == 1]['dif'].mean(), async_exp[async_exp['keylength'] == 2]['dif'].mean(),
         async_exp[async_exp['keylength'] == 3]['dif'].mean(), async_exp[async_exp['keylength'] == 4]['dif'].mean(),
         async_exp[async_exp['keylength'] == 12]['dif'].mean(), async_exp[async_exp['keylength'] == 13]['dif'].mean(),
         async_exp[async_exp['keylength'] == 14]['dif'].mean(), async_exp[async_exp['keylength'] == 15]['dif'].mean(),
         async_exp[async_exp['keylength'] == 16]['dif'].mean()]
async_std = [ np.std(async_exp[async_exp['keylength'] == 1]['dif']), np.std(async_exp[async_exp['keylength'] == 2]['dif']), 
       np.std(async_exp[async_exp['keylength'] == 3]['dif']), np.std(async_exp[async_exp['keylength'] == 4]['dif']),
       np.std(async_exp[async_exp['keylength'] == 12]['dif']), np.std(async_exp[async_exp['keylength'] == 13]['dif']),
       np.std(async_exp[async_exp['keylength'] == 14]['dif']), np.std(async_exp[async_exp['keylength'] == 15]['dif']),
       np.std(async_exp[async_exp['keylength'] == 16]['dif'])]

ax = axs[0]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
ax.set_title('With Async', fontsize=16)
ax.set_xticks(x)
ax.set_ylim(0, 30)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.bar(x, async_means, width, yerr=async_std)
ax = axs[1]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
ax.set_title('No Async', fontsize=16)
ax.set_xticks(x)
ax.set_ylim(0, 30)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.bar(x, ghz26_means, width, yerr=ghz26_std)

fig.tight_layout()
fig.subplots_adjust(top=0.88)
plt.show()
fig.savefig('D:\\elastic-hurryup\\graphs\\async.png')

# %%
fig, axs = plt.subplots(1,2, figsize=(18,10), dpi=300)

labels = ['1.0GHz', '1.3GHz', '1.7GHz', '2.0GHz', '2.3GHz', '2.6GHz']
x = np.arange(len(labels))
width = 0.35
fig.suptitle('95-percentile of Service Time @ Scales = 5', fontsize=22)

async_means = [ async_exp[async_exp['keylength'] == 1]['dif'].mean(), async_exp[async_exp['keylength'] == 2]['dif'].mean(),
         async_exp[async_exp['keylength'] == 3]['dif'].mean(), async_exp[async_exp['keylength'] == 4]['dif'].mean(),
         async_exp[async_exp['keylength'] == 12]['dif'].mean(), async_exp[async_exp['keylength'] == 13]['dif'].mean(),
         async_exp[async_exp['keylength'] == 14]['dif'].mean(), async_exp[async_exp['keylength'] == 15]['dif'].mean(),
         async_exp[async_exp['keylength'] == 16]['dif'].mean()]
async_std = [ np.std(async_exp[async_exp['keylength'] == 1]['dif']), np.std(async_exp[async_exp['keylength'] == 2]['dif']), 
       np.std(async_exp[async_exp['keylength'] == 3]['dif']), np.std(async_exp[async_exp['keylength'] == 4]['dif']),
       np.std(async_exp[async_exp['keylength'] == 12]['dif']), np.std(async_exp[async_exp['keylength'] == 13]['dif']),
       np.std(async_exp[async_exp['keylength'] == 14]['dif']), np.std(async_exp[async_exp['keylength'] == 15]['dif']),
       np.std(async_exp[async_exp['keylength'] == 16]['dif'])]

ax = axs[0]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
ax.set_title('With Async', fontsize=16)
ax.set_xticks(x)
ax.set_ylim(0, 30)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.bar(x, async_means, width, yerr=async_std)
ax = axs[1]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
ax.set_title('No Async', fontsize=16)
ax.set_xticks(x)
ax.set_ylim(0, 30)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.bar(x, ghz26_means, width, yerr=ghz26_std)

fig.tight_layout()
fig.subplots_adjust(top=0.88)
plt.show()
fig.savefig('D:\\elastic-hurryup\\graphs\\async.png')

# %%
# Scale = 5 files
columns_names = ['tid', 'start', 'end', 'query', 'dif', 'keylength']

ghz26_scale5 = pd.read_csv(base_dir + '\\db\\frequencies-noqueue\\2.6ghz-noqueue\\log.txt', names=columns_names)
ghz23_scale5 = pd.read_csv(base_dir + '\\db\\frequencies-noqueue\\2.3ghz-noqueue\\log.txt', names=columns_names)
ghz20_scale5 = pd.read_csv(base_dir + '\\db\\frequencies-noqueue\\2.0ghz-noqueue\\log.txt', names=columns_names)
ghz17_scale5 = pd.read_csv(base_dir + '\\db\\frequencies-noqueue\\1.7ghz-noqueue\\log.txt', names=columns_names)
ghz13_scale5 = pd.read_csv(base_dir + '\\db\\frequencies-noqueue\\1.3ghz-noqueue\\log.txt', names=columns_names)
ghz10_scale5 = pd.read_csv(base_dir + '\\db\\frequencies-noqueue\\1.0ghz-noqueue\\log.txt', names=columns_names)
ghz26_scale5['keylength'] = ghz26_scale5['query'].str.count('\+') + 1
ghz23_scale5['keylength'] = ghz23_scale5['query'].str.count('\+') + 1
ghz20_scale5['keylength'] = ghz20_scale5['query'].str.count('\+') + 1
ghz17_scale5['keylength'] = ghz17_scale5['query'].str.count('\+') + 1
ghz13_scale5['keylength'] = ghz13_scale5['query'].str.count('\+') + 1
ghz10_scale5['keylength'] = ghz10_scale5['query'].str.count('\+') + 1
ghz26_scale5['dif'] = ghz26_scale5['dif']
ghz23_scale5['dif'] = ghz23_scale5['dif']
ghz20_scale5['dif'] = ghz20_scale5['dif']
ghz17_scale5['dif'] = ghz17_scale5['dif']
ghz13_scale5['dif'] = ghz13_scale5['dif']
ghz10_scale5['dif'] = ghz10_scale5['dif']

# %%
fig, axs = plt.subplots(1,2, figsize=(20,8), dpi=300)

labels = ['1.0GHz', '1.3GHz', '1.7GHz', '2.0GHz', '2.3GHz', '2.6GHz']
x = np.arange(len(labels))
width = 0.35
fig.suptitle('99-percentile Service Time per Base Frequency / No Queues', fontsize=22)
bigKw_90p = [ np.percentile(ghz10_scale5[ghz10_scale5['keylength'] > 10]['dif'], 90), 
                np.percentile(ghz13_scale5[ghz13_scale5['keylength'] > 10]['dif'], 90),
                np.percentile(ghz17_scale5[ghz17_scale5['keylength'] > 10]['dif'], 90),
                np.percentile(ghz20_scale5[ghz20_scale5['keylength'] > 10]['dif'], 90),
                np.percentile(ghz23_scale5[ghz23_scale5['keylength'] > 10]['dif'], 90),
                np.percentile(ghz26_scale5[ghz26_scale5['keylength'] > 10]['dif'], 90) ]
lowKw_90p = [ np.percentile(ghz10_scale5[ghz10_scale5['keylength'] < 5]['dif'], 90), 
                np.percentile(ghz13_scale5[ghz13_scale5['keylength'] < 5]['dif'], 90),
                np.percentile(ghz17_scale5[ghz17_scale5['keylength'] < 5]['dif'], 90),
                np.percentile(ghz20_scale5[ghz20_scale5['keylength'] < 5]['dif'], 90),
                np.percentile(ghz23_scale5[ghz23_scale5['keylength'] < 5]['dif'], 90),
                np.percentile(ghz26_scale5[ghz26_scale5['keylength'] < 5]['dif'], 90) ]

ax = axs[0]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Frequencies')
ax.set_title('Lower Keylength (<5)', fontsize=16)
ax.set_xticks(x)
ax.set_ylim(0, 2000)
ax.set_xticklabels((labels))
ax.bar(x, lowKw_90p, width)
ax = axs[1]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Frequencies')
ax.set_title('Higher Keylength (>10)', fontsize=16)
ax.set_xticks(x)
ax.set_ylim(0, 2000)
ax.set_xticklabels((labels))
ax.bar(x, bigKw_90p, width)
fig.tight_layout()
fig.subplots_adjust(top=0.88)
plt.show()
fig.savefig('D:\\elastic-hurryup\\graphs\\lower_vs_higher_kw.png')

# %%
ghz15_scale5['dif'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-111-3af38a8e6f8f> in <module>
# ----> 1 ghz15_scale5['dif'].mean()
#
# NameError: name 'ghz15_scale5' is not defined

# %%
ghz10_scale5

# %%
(3*np.percentile(ghz13_scale5[ghz13_scale5['keylength'] < 5]['dif'], 50) + np.percentile(ghz13_scale5[ghz13_scale5['keylength'] > 10]['dif'],50))/4
# Out:
# 172.75

# %%
base_dir = "D:\elastic-hurryup"
columns_names = ['start', 'end', 'query', 'dif', 'keylength']



ghz26_shard80 = pd.read_csv(base_dir + '\\db\\shards-withqueue\\5shards-80gbindex\\log.txt', names=columns_names)
ghz26_shard40 = pd.read_csv(base_dir + '\\db\\shards-withqueue\\5shards-40gbindex-reindex2\\log.txt', names=columns_names)
ghz26_1shard40 = pd.read_csv(base_dir + '\\db\\shards-withqueue\\1shard-40gbindex\\log.txt', names=columns_names)
ghz26_shard80['keylength'] = ghz26_shard80['query'].str.count('\+') + 1
ghz26_shard40['keylength'] = ghz26_shard40['query'].str.count('\+') + 1
ghz26_1shard40['keylength'] = ghz26_1shard40['query'].str.count('\+') + 1

# %%
means = [ghz26_1shard40[ghz26_1shard40['keylength'] > 10]['dif'].mean(), ghz26_shard40[ghz26_shard40['keylength'] > 10]['dif'].mean(), ghz26_shard80[ghz26_shard80['keylength'] > 10]['dif'].mean()]
ninefive = [np.percentile(ghz26_1shard40[ghz26_1shard40['keylength'] > 10]['dif'], 95),  np.percentile(ghz26_shard40[ghz26_shard40['keylength'] > 10]['dif'], 95),  np.percentile(ghz26_shard80[ghz26_shard80['keylength'] > 10]['dif'], 95)]
ninenine = [np.percentile(ghz26_1shard40[ghz26_1shard40['keylength'] > 10]['dif'], 99), np.percentile(ghz26_shard40[ghz26_shard40['keylength'] > 10]['dif'], 99),  np.percentile(ghz26_shard80[ghz26_shard80['keylength'] > 10]['dif'], 99)]
means_std = [np.std(ghz26_1shard40[ghz26_1shard40['keylength'] > 10]['dif']), np.std(ghz26_shard40[ghz26_shard40['keylength'] > 10]['dif']), np.std(ghz26_shard80[ghz26_shard80['keylength'] > 10]['dif'])]

labels = ['1x 40GB', '5x 8 GB', '5x 15 GB']


x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots(figsize=(12,8), dpi=300)
rects1 = ax.bar(x - width, np.round(means, 0), width, label='Mean', yerr=means_std)
rects2 = ax.bar(x, np.round(ninefive, 0), width, label='95-percentile')
rects3 = ax.bar(x + width, np.round(ninenine, 0), width, label='99-percentile')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Service Time (ms)')
ax.set_title('Service Time by Number of Shards and its Physical Size')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)


#fig.tight_layout()

plt.show()
fig.savefig('D:\\elastic-hurryup\\graphs\\shards-size-comparison.png')

# %%
base_dir = "D:\elastic-hurryup"
columns_names = ['coreid', 'start', 'end', 'query', 'dif', 'keylength']


hup = pd.read_csv(base_dir + '\\db\\hup-withstats-300msthreshold-50mssample\\log.txt', names=columns_names)
ondem = pd.read_csv(base_dir + '\\db\\ondemand-withstats\\log.txt', names=columns_names)
hup['keylength'] = hup['query'].str.count('\+') + 1
ondem['keylength'] = ondem['query'].str.count('\+') + 1

# %%
fig, axs = plt.subplots(1,2, figsize=(18,10), dpi=300)

labels = ['1', '2', '3', '4', '12', '13', '14', '15', '16']
x = np.arange(len(labels))
width = 0.35
fig.suptitle('Service Time on HUP vs Ondemand', fontsize=22)

ondem_means = [ np.percentile(ondem[ondem['keylength'] == 1]['dif'], 90), np.percentile(ondem[ondem['keylength'] == 2]['dif'], 90),
         np.percentile(ondem[ondem['keylength'] == 3]['dif'], 90), np.percentile(ondem[ondem['keylength'] == 4]['dif'], 90),
         np.percentile(ondem[ondem['keylength'] == 12]['dif'], 90), np.percentile(ondem[ondem['keylength'] == 13]['dif'], 90),
         np.percentile(ondem[ondem['keylength'] == 14]['dif'], 90), np.percentile(ondem[ondem['keylength'] == 15]['dif'], 90),
         np.percentile(ondem[ondem['keylength'] == 16]['dif'], 90)]

hup_means = [ np.percentile(hup[hup['keylength'] == 1]['dif'], 90), np.percentile(hup[hup['keylength'] == 2]['dif'], 90),
         np.percentile(hup[hup['keylength'] == 3]['dif'], 90), np.percentile(hup[hup['keylength'] == 4]['dif'], 90),
         np.percentile(hup[hup['keylength'] == 12]['dif'], 90), np.percentile(hup[hup['keylength'] == 13]['dif'], 90),
         np.percentile(hup[hup['keylength'] == 14]['dif'], 90), np.percentile(hup[hup['keylength'] == 15]['dif'], 90),
         np.percentile(hup[hup['keylength'] == 16]['dif'], 90)]

ax = axs[0]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
ax.set_title('ondem', fontsize=16)
ax.set_xticks(x)
ax.set_ylim(0, 1000)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.bar(x, ondem_means, width)
ax = axs[1]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
ax.set_title('Hup', fontsize=16)
ax.set_xticks(x)
ax.set_ylim(0, 1000)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.bar(x, hup_means, width)

fig.tight_layout()
fig.subplots_adjust(top=0.88)
plt.show()
fig.savefig('D:\\elastic-hurryup\\graphs\\hup_vs_ondem.png')

# %%
hupts_end = pd.read_csv(base_dir + '\\db\\hup-withstats-300msthreshold-50mssample\\time_in_state_end.txt', sep=" ", header=None, names=["freq", "time"])
hupts_init = pd.read_csv(base_dir + '\\db\\hup-withstats-300msthreshold-50mssample\\time_in_state_init.txt', sep=" ", header=None, names=["freq", "time"])
hupts = hupts_end['time'] - hupts_init['time']
ondemts_end = pd.read_csv(base_dir + '\\db\\ondemand-withstats\\time_in_state_end.txt', sep=" ", header=None, names=["freq", "time"])
ondemts_init = pd.read_csv(base_dir + '\\db\\ondemand-withstats\\time_in_state_init.txt', sep=" ", header=None, names=["freq", "time"])
ondemts = ondemts_end['time'] - ondemts_init['time']

# %%
from matplotlib import rcParams
rcParams['axes.titlepad'] = 10 

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
        
fig, axs = plt.subplots(2,1, figsize=(18,10), dpi=300, sharex=True)

labels = ['1.0GHz', '1.1GHz', '1.2GHz', '1.3GHz', '1.5GHz', '1.6GHz', '1.7GHz', '1.8GHz', '1.9GHz', '2.0GHz', '2.1GHz', '2.3GHz', '2.4GHz', '2.5GHz', '2.6GHz']
x = np.arange(len(labels))
width = 0.35
fig.suptitle('Comparison of Time-in-state Tables for Ondemand/Hurryup', fontsize=22,y=1.05)

ondem_tsbar = [ ondemts[15], ondemts[14], ondemts[13], ondemts[12], ondemts[11], ondemts[10], 
               ondemts[9], ondemts[8], ondemts[7], ondemts[6], ondemts[5], 
               ondemts[4], ondemts[3],ondemts[2], ondemts[1]]

hup_tsbar = [ hupts[15], hupts[14], hupts[13], hupts[12], hupts[11], hupts[10], 
               hupts[9], hupts[8], hupts[7], hupts[6], hupts[5], 
               hupts[4], hupts[3],hupts[2], hupts[1]]

ax = axs[0]
ax.set_ylabel('Service Time (ms)')
#ax.set_xlabel('Keyword Length (unit)')
ax.set_title('Governor@Ondemand', fontsize=16)
ax.set_xticks(x)
ax.set_ylim(0, 75000)
ax.set_xticklabels(labels)
bartsondem = ax.bar(x, ondem_tsbar, width)
autolabel(bartsondem)
ax = axs[1]
ax.set_ylabel('Time in Each State (ms)')
ax.set_xlabel('Frequencies (unit)')
ax.set_title('Governor@Userspace with Hurryup', fontsize=16)
ax.set_xticks(x)
ax.set_ylim(0, 75000)
ax.set_xticklabels((labels))
bartshup = ax.bar(x, hup_tsbar, width)
autolabel(bartshup)
#fig.subplots_adjust(top=0.88)
fig.tight_layout()
plt.show()
fig.savefig('D:\\elastic-hurryup\\graphs\\hup_vs_ondem_ts.png')

# %%
ondem_tsbar.get_height
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-104-5a1faec0c255> in <module>
# ----> 1 ondem_tsbar.get_height
#
# AttributeError: 'list' object has no attribute 'get_height'

# %%
ondem['keylength'].value_counts().hist()
hup['keylength'].value_counts().hist()

# %%
base_dir = "D:\elastic-hurryup"
columns_names = ['coreid', 'start', 'end', 'query', 'dif', 'keylength']


hup = pd.read_csv(base_dir + '\\db\\hurryup-multfreq\\log.txt', names=columns_names)
ondem = pd.read_csv(base_dir + '\\db\\ondemand-12threads\\log.txt', names=columns_names)
hup['keylength'] = hup['query'].str.count('\+') + 1
ondem['keylength'] = ondem['query'].str.count('\+') + 1

# %%
fig, axs = plt.subplots(1,2, figsize=(18,10), dpi=300)

labels = ['1', '2', '3', '4', '12', '13', '14', '15', '16']
x = np.arange(len(labels))
width = 0.35
fig.suptitle('Service Time on Ondem vs HUP', fontsize=22)

ondem_means = [ np.percentile(ondem[ondem['keylength'] == 1]['dif'], 90), np.percentile(ondem[ondem['keylength'] == 2]['dif'], 90),
         np.percentile(ondem[ondem['keylength'] == 3]['dif'], 90), np.percentile(ondem[ondem['keylength'] == 4]['dif'], 90),
         np.percentile(ondem[ondem['keylength'] == 12]['dif'], 90), np.percentile(ondem[ondem['keylength'] == 13]['dif'], 90),
         np.percentile(ondem[ondem['keylength'] == 14]['dif'], 90), np.percentile(ondem[ondem['keylength'] == 15]['dif'], 90),
         np.percentile(ondem[ondem['keylength'] == 16]['dif'], 90)]

hup_means = [ np.percentile(hup[hup['keylength'] == 1]['dif'], 90), np.percentile(hup[hup['keylength'] == 2]['dif'], 90),
         np.percentile(hup[hup['keylength'] == 3]['dif'], 90), np.percentile(hup[hup['keylength'] == 4]['dif'], 90),
         np.percentile(hup[hup['keylength'] == 12]['dif'], 90), np.percentile(hup[hup['keylength'] == 13]['dif'], 90),
         np.percentile(hup[hup['keylength'] == 14]['dif'], 90), np.percentile(hup[hup['keylength'] == 15]['dif'], 90),
         np.percentile(hup[hup['keylength'] == 16]['dif'], 90)]

ax = axs[0]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
ax.set_title('Ondem', fontsize=16)
ax.set_xticks(x)
ax.set_ylim(0, 1000)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.bar(x, ondem_means, width)
ax = axs[1]
ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
ax.set_title('HUP without Freq. Change', fontsize=16)
ax.set_xticks(x)
ax.set_ylim(0, 1000)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
ax.bar(x, hup_means, width)

fig.tight_layout()
fig.subplots_adjust(top=0.88)
plt.show()
#fig.savefig('D:\\elastic-hurryup\\graphs\\hup-nofreqchange_vs_10ghz.png')

# %%
hupts_end = pd.read_csv(base_dir + '\\db\\hurryup-with_mult_freqs\\time_in_state_end.txt', sep=" ", header=None, names=["freq", "time"])
hupts_init = pd.read_csv(base_dir + '\\db\\hurryup-with_mult_freqs\\time_in_state_init.txt', sep=" ", header=None, names=["freq", "time"])
hupts = hupts_end['time'] - hupts_init['time']
ondemts_end = pd.read_csv(base_dir + '\\db\\ondemand-12threads\\time_in_state_end.txt', sep=" ", header=None, names=["freq", "time"])
ondemts_init = pd.read_csv(base_dir + '\\db\\ondemand-12threads\\time_in_state_init.txt', sep=" ", header=None, names=["freq", "time"])
ondemts = ondemts_end['time'] - ondemts_init['time']

# %%
from matplotlib import rcParams
rcParams['axes.titlepad'] = 10 

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
        
fig, axs = plt.subplots(2,1, figsize=(18,10), dpi=300, sharex=True)

labels = ['1.0GHz', '1.1GHz', '1.2GHz', '1.3GHz', '1.5GHz', '1.6GHz', '1.7GHz', '1.8GHz', '1.9GHz', '2.0GHz', '2.1GHz', '2.3GHz', '2.4GHz', '2.5GHz', '2.6GHz']
x = np.arange(len(labels))
width = 0.35
fig.suptitle('Comparison of Time-in-state Tables for Ondemand/Hurryup', fontsize=22,y=1.05)

ondem_tsbar = [ ondemts[15], ondemts[14], ondemts[13], ondemts[12], ondemts[11], ondemts[10], 
               ondemts[9], ondemts[8], ondemts[7], ondemts[6], ondemts[5], 
               ondemts[4], ondemts[3],ondemts[2], ondemts[1]]

hup_tsbar = [ hupts[15], hupts[14], hupts[13], hupts[12], hupts[11], hupts[10], 
               hupts[9], hupts[8], hupts[7], hupts[6], hupts[5], 
               hupts[4], hupts[3],hupts[2], hupts[1]]

ax = axs[0]
ax.set_ylabel('Service Time (ms)')
#ax.set_xlabel('Keyword Length (unit)')
ax.set_title('Governor@Ondemand', fontsize=16)
ax.set_xticks(x)
ax.set_ylim(0, 75000)
ax.set_xticklabels(labels)
bartsondem = ax.bar(x, ondem_tsbar, width)
autolabel(bartsondem)
ax = axs[1]
ax.set_ylabel('Time in Each State (ms)')
ax.set_xlabel('Frequencies (unit)')
ax.set_title('Governor@Ondemand with Hurryup', fontsize=16)
ax.set_xticks(x)
#ax.set_ylim(0, 75000)
ax.set_xticklabels((labels))
bartshup = ax.bar(x, hup_tsbar, width)
autolabel(bartshup)
#fig.subplots_adjust(top=0.88)
fig.tight_layout()
plt.show()
#fig.savefig('D:\\elastic-hurryup\\graphs\\ondemhup2_vs_ondem_ts.png')

# %%
fig, ax = plt.subplots(figsize=(18,10), dpi=300)

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

labels = ['1', '2', '3', '4', '12', '13', '14', '15', '16']
x = np.arange(len(labels))
width = 0.35
fig.suptitle('Overhead Measurement - Hurryup (Only 1.0Ghz Change) / 1.0 Ghz Normal', fontsize=22)

ondem_means = [ np.percentile(ondem[ondem['keylength'] == 1]['dif'], 90), np.percentile(ondem[ondem['keylength'] == 2]['dif'], 90),
         np.percentile(ondem[ondem['keylength'] == 3]['dif'], 90), np.percentile(ondem[ondem['keylength'] == 4]['dif'], 90),
         np.percentile(ondem[ondem['keylength'] == 12]['dif'], 90), np.percentile(ondem[ondem['keylength'] == 13]['dif'], 90),
         np.percentile(ondem[ondem['keylength'] == 14]['dif'], 90), np.percentile(ondem[ondem['keylength'] == 15]['dif'], 90),
         np.percentile(ondem[ondem['keylength'] == 16]['dif'], 90)]

hup_means = [ np.percentile(hup[hup['keylength'] == 1]['dif'], 90), np.percentile(hup[hup['keylength'] == 2]['dif'], 90),
         np.percentile(hup[hup['keylength'] == 3]['dif'], 90), np.percentile(hup[hup['keylength'] == 4]['dif'], 90),
         np.percentile(hup[hup['keylength'] == 12]['dif'], 90), np.percentile(hup[hup['keylength'] == 13]['dif'], 90),
         np.percentile(hup[hup['keylength'] == 14]['dif'], 90), np.percentile(hup[hup['keylength'] == 15]['dif'], 90),
         np.percentile(hup[hup['keylength'] == 16]['dif'], 90)]

ax.set_ylabel('Service Time (ms)')
ax.set_xlabel('Keyword Length (unit)')
#ax.set_title('Ondem', fontsize=16)
ax.set_xticks(x)
ax.set_ylim(0, 1.5)
ax.set_xticklabels(('1', '2', '3', '4', '12', '13', '14', '15', '16'))
rr = ax.bar(x, np.array(hup_means)/np.array(ondem_means), width)
autolabel(rr)
fig.tight_layout()
fig.subplots_adjust(top=0.88)
plt.show()
fig.savefig('D:\\elastic-hurryup\\graphs\\overhead.png')

# %%
base_dir = "D:\elastic-hurryup"
columns_names = ['coreid', 'start', 'end', 'query', 'dif', 'keylength']

thres100 = pd.read_csv(base_dir + '\\db\\hup-to2.6ghz-thres100\\log.txt', names=columns_names)
thres200 = pd.read_csv(base_dir + '\\db\\hup-to2.6ghz-thres200\\log.txt', names=columns_names)
thres300 = pd.read_csv(base_dir + '\\db\\hup-to2.6ghz-thres300\\log.txt', names=columns_names)
thres400 = pd.read_csv(base_dir + '\\db\\hup-to2.6ghz-thres400\\log.txt', names=columns_names)
thres500 = pd.read_csv(base_dir + '\\db\\hup-to2.6ghz-thres500\\log.txt', names=columns_names)
thres600 = pd.read_csv(base_dir + '\\db\\hup-to2.6ghz-thres600\\log.txt', names=columns_names)
thres700 = pd.read_csv(base_dir + '\\db\\hup-to2.6ghz-thres700\\log.txt', names=columns_names)
thres800 = pd.read_csv(base_dir + '\\db\\hup-to2.6ghz-thres800\\log.txt', names=columns_names)
thres900 = pd.read_csv(base_dir + '\\db\\hup-to2.6ghz-thres900\\log.txt', names=columns_names)
thres1000 = pd.read_csv(base_dir + '\\db\\hup-to2.6ghz-thres1000\\log.txt', names=columns_names)

# %%
x = { '100ms': 1, '200ms': 2, '300ms': 3, '400ms': 4, '500ms': 5, '600ms': 6, '700ms': 7, '800ms': 8, '900ms': 9, '1000ms': 10}
names = list(x.keys())
values = list(x.values())
y = [ 0.600, 0.608, 0.623, 0.613, 0.648, 0.635, 0.690, 0.680, 0.610, 0.775]
e = [ 0.131, 0.132, 0.133, 0.137, 0.141, 0.140, 0.145, 0.147, 0.138, 0.158]

# %%
plt.errorbar(names, y, e, linestyle='None', marker='^')
plt.axhline(y=0.515)
plt.axhline(y=0.632)
